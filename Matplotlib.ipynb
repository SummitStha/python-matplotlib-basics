# %%
#### Matplotlib is a plotting library. In this section give a brief introduction to the matplotlib.pyplot module, which provides a plotting system similar to that of MATLAB.

# %% [markdown]
# #### Importing numpy as np and pyplot module from matplotlib library and naming it as plt

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### By running this special iPython command, we will be displaying plots inline:

# %%
# %matplotlib inline

# %% [markdown]
# ### Plotting

# %% [markdown]
# ####  The most important function in matplotlib is plot, which allows you to plot 2D data. Here is a simple example:

# %%
# Compute the x and y coordinates for points on a sine curve
x = np.arange(0, 3 * np.pi, 0.1)
y = np.sin(x)

# Plot the points using matplotlib
plt.plot(x, y)

# %% [markdown]
# #### With just a little bit of extra work we can easily plot multiple lines at once, and add a title, legend, and axis labels:

# %%
y_sin = np.sin(x)
y_cos = np.cos(x)

# Plot the points using matplotlib
plt.plot(x, y_sin)
plt.plot(x, y_cos)
plt.xlabel('x axis label')
plt.ylabel('y axis label')
plt.title('Sine and Cosine')
plt.legend(['Sine', 'Cosine'])

# %% [markdown]
# ### Subplots

# %% [markdown]
# #### You can plot different things in the same figure using the subplot function. Here is an example:

# %%
# Compute the x and y coordinates for points on sine and cosine curves
x = np.arange(0, 3 * np.pi, 0.1)
y_sin = np.sin(x)
y_cos = np.cos(x)
y_tan = np.tan(x)

# Set up a subplot grid that has height 2 and width 1,
# and set the first such subplot as active.
plt.subplot(3, 1, 1)    #(height, width, which index to plot)

# Make the first plot
plt.plot(x, y_sin)
plt.title('Sine')

# Set the second subplot as active, and make the second plot.
plt.subplot(3, 1, 2)
plt.plot(x, y_cos)
plt.title('Cosine')

# Set the second subplot as active, and make the second plot.
plt.subplot(3, 1, 3)
plt.plot(x, y_tan)
plt.title('Tan')

# Show the figure.
plt.show()

# %%
# scatterplots - used to show correlation or relationship between variables(basically)
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6,7,8]
y=[4,5,7,2,1,4,12,7]
#we can pass color parameter to specify the color,generally first letter of the color can be passed as value
#for example 'b' for blue 'g; for green.
# marker parameter specifies the type by which we can denote the scatter points .matplotlib has pre defined
#vaues for marker like '*' , '+' ,etc.
plt.scatter(x,y,label='scatertest',color='b',marker='+')
plt.xlabel('x')
plt.ylabel('y')
plt.title('interesting graph\ncheck it out')
plt.legend()
plt.show()

# %% [markdown]
# #### You can read much more about the subplot function in the documentation.
